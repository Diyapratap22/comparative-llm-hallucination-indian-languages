# %% [markdown]
# # Exploratory Analysis
#
# **Status:** placeholder notebook — no analysis has been run and no data
# exists yet.
#
# Planned contents (once the experiment and annotation are complete):
#
# - load annotated responses from `annotations/final_labels`
# - descriptive statistics: hallucination rates by language, category, and model
# - visualizations (per-language, per-category, and per-model comparisons)
# - statistical tests from `analysis/statistical_tests.py`
# - error analysis from `analysis/error_analysis.py`
#
# Do not run this notebook until a complete experiment run and finalized
# annotations exist.
